# %%
import os
os.environ["TRANSFORMERS_NO_TF"] = "1"

# %%
import json

# Load Harsh's cleaned ABSA output
with open("models/absa/task3_cleaned_aspects.json", "r") as f:
    data = json.load(f)

print("Data loaded successfully")
print("Total reviews:", len(data))
# Out:
# Data loaded successfully
# Total reviews: 5000

# %%
all_aspects = []

for review_id, aspects in data.items():
    for item in aspects:
        aspect = item["aspect"].lower().strip()
        all_aspects.append(aspect)

print("Total aspect mentions:", len(all_aspects))
# Out:
# Total aspect mentions: 76172

# %%
unique_aspects = list(set(all_aspects))

print("Unique aspects:", len(unique_aspects))
print("\nSample aspects:")
print(unique_aspects[:30])
# Out:
# Unique aspects: 27860
#
# Sample aspects:
# ['some consistency', 'one thing', 'super sale', 'your dish', 'donut shop decaf', 'all 5g saffron', 'upcoming v day', 'three hundred 2 cracker cellophane packs', 'rice based food', 'rossi pizza sauce', 'locals stores', 'adobo', 'deen', 'one 6 oz bone', 'wv', 'carbonated water', 'her own groceries', 'mountain sun cranberry juice', 'falling droplets', 'good idea', 'hemp seeds', 'any other brands', 'lick ball', '6 oz oil', 'only option', 'energy drinks', 'tallest kids', '60 wraps', 'best way', '3 5 minutes']

# %%
def strong_filter(a):
    a = a.lower().strip()
    
    # remove non-letters
    import re
    a = re.sub(r'[^a-zA-Z\s]', '', a)
    
    words = a.split()
    
    # keep ONLY 1–2 word phrases
    if len(words) > 2:
        return None
    
    # remove very short words
    if len(a) < 3:
        return None
    
    return a

# %%
cleaned_aspects = []

for a in unique_aspects:
    a_clean = strong_filter(a)
    if a_clean:
        cleaned_aspects.append(a_clean)

cleaned_aspects = list(set(cleaned_aspects))

print("After strong filter:", len(cleaned_aspects))
print(cleaned_aspects[:30])
# Out:
# After strong filter: 17334
# [' teabags', 'some consistency', 'no plans', 'bulk amount', 'snaps', 'salmonella contamination', 'complete disgust', '  cacoa chocolate', 'cries', 'yellow jackets', 'our dermatologist', 'fake lime', 'tupperware', 'one thing', 'nut snack', 'their competition', 'super sale', 'plunge', 'no amount', 'burger king', 'chores', 'south', 'her gsd', 'your dish', 'moisterizer', 'usual coffee', 'nickel', 'tart', 'any flavoring', 'factor']

# %%
bad_words = {
    "thing", "product", "item", "stuff", "something",
    "anything", "everything", "nothing",
    "time", "day", "way", "lot", "kind",
    "same", "many", "little", "great"
}

filtered_aspects = [
    a for a in cleaned_aspects
    if a not in bad_words
]

print("After removing generic:", len(filtered_aspects))
print(filtered_aspects[:30])
# Out:
# After removing generic: 17333
# [' teabags', 'some consistency', 'no plans', 'bulk amount', 'snaps', 'salmonella contamination', 'complete disgust', '  cacoa chocolate', 'cries', 'yellow jackets', 'our dermatologist', 'fake lime', 'tupperware', 'one thing', 'nut snack', 'their competition', 'super sale', 'plunge', 'no amount', 'burger king', 'chores', 'south', 'her gsd', 'your dish', 'moisterizer', 'usual coffee', 'nickel', 'tart', 'any flavoring', 'factor']

# %%
from collections import Counter

aspect_counts = Counter(all_aspects)

filtered_aspects = [
    a for a in filtered_aspects
    if aspect_counts[a] >= 10   # increase threshold
]

print("Final aspect count:", len(filtered_aspects))
# Out:
# Final aspect count: 717

# %%
import subprocess
subprocess.run(["pip", "install", "-U", "sentence-transformers", "huggingface_hub"], 
               capture_output=True)
# Out:
# CompletedProcess(args=['pip', 'install', '-U', 'sentence-transformers', 'huggingface_hub'], returncode=0, stdout=b'Requirement already satisfied: sentence-transformers in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (2.2.2)\nCollecting sentence-transformers\n  Downloading sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)\nRequirement already satisfied: huggingface_hub in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (0.14.1)\nCollecting huggingface_hub\n  Downloading huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)\nCollecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)\n  Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)\nRequirement already satisfied: tqdm in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from sentence-transformers) (4.67.1)\nRequirement already satisfied: torch>=1.11.0 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from sentence-transformers) (2.8.0)\nRequirement already satisfied: scikit-learn in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from sentence-transformers) (1.6.1)\nRequirement already satisfied: scipy in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from sentence-transformers) (1.13.1)\nRequirement already satisfied: Pillow in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from sentence-transformers) (11.3.0)\nRequirement already satisfied: typing_extensions>=4.5.0 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from sentence-transformers) (4.15.0)\nRequirement already satisfied: filelock in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.19.1)\nCollecting huggingface_hub\n  Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)\nRequirement already satisfied: numpy>=1.17 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.24.3)\nRequirement already satisfied: packaging>=20.0 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)\nRequirement already satisfied: pyyaml>=5.1 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)\nRequirement already satisfied: regex!=2019.12.17 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)\nRequirement already satisfied: requests in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)\nCollecting tokenizers<=0.23.0,>=0.22.0 (from transformers<5.0.0,>=4.41.0->sentence-transformers)\n  Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.3 kB)\nRequirement already satisfied: safetensors>=0.4.3 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)\nRequirement already satisfied: fsspec>=2023.5.0 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from huggingface_hub) (2025.10.0)\nRequirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from huggingface_hub) (1.2.0)\nRequirement already satisfied: sympy>=1.13.3 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)\nRequirement already satisfied: networkx in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)\nRequirement already satisfied: jinja2 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)\nRequirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kanishkagupta/main-env/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)\nRequirement  ...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
print("Model loaded successfully")
# Out:
# /Users/kanishkagupta/main-env/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Model loaded successfully

# %%
import re
import json
import numpy as np
import pandas as pd
from collections import Counter, defaultdict
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize

# ── Fix: properly clean aspects before frequency count ────────────────────────
def strong_filter(a):
    a = a.lower().strip()
    a = re.sub(r'[^a-zA-Z\s]', '', a)
    a = a.strip()  # strip AGAIN after regex
    words = a.split()
    if len(words) > 2 or len(a) < 3:
        return None
    return a

bad_words = {
    "thing", "product", "item", "stuff", "something",
    "anything", "everything", "nothing", "time", "day",
    "way", "lot", "kind", "same", "many", "little", "great"
}

# Re-extract with fix: track cleaned aspect → original mentions
with open("models/absa/task3_cleaned_aspects.json", "r") as f:
    data = json.load(f)

# Count on CLEANED aspects (this was the subtle bug before)
cleaned_mention_counts = Counter()
review_aspect_map = {}  # review_id → [(cleaned_aspect, sentiment)]

for review_id, aspects in data.items():
    cleaned_pairs = []
    for item in aspects:
        raw = item["aspect"].lower().strip()
        cleaned = strong_filter(raw)
        if cleaned and cleaned not in bad_words:
            cleaned_mention_counts[cleaned] += 1
            cleaned_pairs.append((cleaned, item["sentiment"]))
    review_aspect_map[review_id] = cleaned_pairs

# Final vocabulary: aspects appearing >= 10 times
final_aspects = [a for a, c in cleaned_mention_counts.items() if c >= 10]
final_aspect_set = set(final_aspects)
print(f"Final vocabulary size: {len(final_aspects)}")

# ── Step 1: Embed aspects ─────────────────────────────────────────────────────
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(final_aspects, show_progress_bar=True)
embeddings = normalize(embeddings)  # normalize for cosine similarity

# ── Step 2: KMeans clustering ─────────────────────────────────────────────────
N_CLUSTERS = 25
kmeans = KMeans(n_clusters=N_CLUSTERS, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(embeddings)

# ── Step 3: Inspect clusters so YOU can name the taxonomy ────────────────────
cluster_df = pd.DataFrame({
    "aspect": final_aspects,
    "cluster": cluster_labels
})

print("\n── Cluster Preview (top 10 aspects per cluster) ──")
for cid in range(N_CLUSTERS):
    members = cluster_df[cluster_df["cluster"] == cid]["aspect"].tolist()
    print(f"\nCluster {cid} ({len(members)} aspects):")
    print("  ", members[:10])
# Out:
# Final vocabulary size: 747
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# ── Cluster Preview (top 10 aspects per cluster) ──
#
# Cluster 0 (28 aspects):
#    ['peanuts', 'almonds', 'vegetables', 'fruit', 'sweet potato', 'carrots', 'apples', 'blueberry', 'seeds', 'cereal']
#
# Cluster 1 (11 aspects):
#    ['no issues', 'any way', 'no problem', 'no luck', 'good deal', 'no problems', 'only problem', 'no idea', 'great deal', 'no interest']
#
# Cluster 2 (36 aspects):
#    ['air', 'chews', 'tongue', 'teeth', 'bite', 'your body', 'bones', 'your teeth', 'body', 'mouth']
#
# Cluster 3 (38 aspects):
#    ['tea', 'cup', 'caffeine', 'drink', 'coffee', 'brew', 'green tea', 'strong coffee', 'keurig', 'caramel']
#
# Cluster 4 (49 aspects):
#    ['these', 'end', 'hassle', 'son', 'real thing', 'course', 'junk', 'those', 'can', 'exactly what']
#
# Cluster 5 (34 aspects):
#    ['flavor', 'taste', 'cinnamon', 'vanilla', 'chocolate', 'cocoa', 'recipe', 'flavors', 'other flavors', 'candy']
#
# Cluster 6 (28 aspects):
#    ['bag', 'bags', 'bars', 'bottles', 'cans', 'cookies', 'bulk', 'each bag', 'pouches', 'pouch']
#
# Cluster 7 (24 aspects):
#    ['days', 'weeks', 'minutes', 'year', 'date', 'same time', 'times', 'years', 'hours', 'while']
#
# Cluster 8 (12 aspects):
#    ['reviews', 'review', 'other reviewers', 'disappointment', 'opinion', 'first time', 'one time', 'other reviews', 'another', 'rating']
#
# Cluster 9 (21 aspects):
#    ['freezer', 'emeril', 'costco', 'amazon', 'stores', 'fridge', 'desk', 'customer service', 'store', 'grocery store']
#
# Cluster 10 (16 aspects):
#    ['container', 'packaging', 'pack', 'packs', 'box', 'delivery', 'package', 'boxes', 'items', 'packages']
#
# Cluster 11 (30 aspects):
#    ['mistake', 'example', 'result', 'research', 'problem', 'drops', 'issue', 'subscribe', 'version', 'update']
#
# Cluster 12 (39 aspects):
#    ['half', 'case', 'bit', 'other things', 'bunch', 'total', 'all', 'each', 'ones', 'whole lot']
#
# Cluster 13 (30 aspects):
#    ['you', 'them', 'they', 'who', 'friends', 'her', 'which', 'myself', 'someone', 'him']
#
# Cluster 14 (12 aspects):
#    ['five stars', 'stars', 'star', 'jar', 'bill', 'two stars', 'zero stars', 'ball', 'one star', 'peach']
#
# Cluster 15 (37 aspects):
#    ['freshness', 'milk', 'cream', 'spice', 'aroma', 'honey', 'ginger', 'oils', 'water', 'juice']
#
# Cluster 16 (58 aspects):
#    ['food', 'dog food', 'peanut butter', 'foods', 'spoon', 'servings', 'dry food', 'stomach', 'wet food', 'cake']
#
# Cluster 17 (21 aspects):
#    ['same product', 'advantage', 'brand', 'manufacturer', 'company', 'other brands', 'convenience', 'different brand', 'another brand', 'great product']
#
# Cluster 18 (41 aspects):
#    ['list', 'garbage', 'label', 'things', 'contents', 'attention', 'type', 'quality', 'paper', 'experience']
#
# Cluster 19 (31 aspects):
#    ['subscription', 'price', 'value', 'cost', 'purchase', 'pricing', 'shipping', 'market', 'sale', 'seller']
#
# Cluster 20 (18 aspects):
#    ['mine', 'fact', 'reason', 'comments', 'huge fan', 'no way', 'fan', 'choice', 'favorites', 'only way']
#
# Cluster 21 (21 aspects):
#    ['calories', 'grams', 'ounces', 'small amount', 'ounce', 'weight', 'tons', 'size', 'cents', 'amount']
#
# Cluster 22 (62 aspects):
#    ['work', 'guests', 'machine', 'money', 'bottom', 'family', 'future', 'house', 'mother', 'country']
#
# Cluster 23 (34 aspects):
#    ['ingredients', 'treat', 'ingredients list', 'sugars', 'sugar', 'sodium', 'pill', 'aspartame', 'splenda', 'stevia']
#
# Cluster 24 (16 aspects):
#    ['cats', 'kids', 'children', 'dogs', 'your dog', 'vet', 'your cat', 'our cats', 'dog', 'animals']

# %%
for cid in range(N_CLUSTERS):
    members = cluster_df[cluster_df["cluster"] == cid]["aspect"].tolist()
    print(f"\nCluster {cid} ({len(members)} aspects):")
    print("  ", members[:15])
    print()
# Out:
# Cluster 0 (28 aspects):
#    ['peanuts', 'almonds', 'vegetables', 'fruit', 'sweet potato', 'carrots', 'apples', 'blueberry', 'seeds', 'cereal', 'veggies', 'beans', 'rice', 'pepper', 'blueberries']
#
#
# Cluster 1 (11 aspects):
#    ['no issues', 'any way', 'no problem', 'no luck', 'good deal', 'no problems', 'only problem', 'no idea', 'great deal', 'no interest', 'deal']
#
#
# Cluster 2 (36 aspects):
#    ['air', 'chews', 'tongue', 'teeth', 'bite', 'your body', 'bones', 'your teeth', 'body', 'mouth', 'other hand', 'face', 'pinch', 'your mouth', 'touch']
#
#
# Cluster 3 (38 aspects):
#    ['tea', 'cup', 'caffeine', 'drink', 'coffee', 'brew', 'green tea', 'strong coffee', 'keurig', 'caramel', 'k cups', 'coffee maker', 'coffee grounds', 'coffee people', 'instant coffee']
#
#
# Cluster 4 (49 aspects):
#    ['these', 'end', 'hassle', 'son', 'real thing', 'course', 'junk', 'those', 'can', 'exactly what', 'yuck', 'what', 'jerky', 'thanks', 'itself']
#
#
# Cluster 5 (34 aspects):
#    ['flavor', 'taste', 'cinnamon', 'vanilla', 'chocolate', 'cocoa', 'recipe', 'flavors', 'other flavors', 'candy', 'dark chocolate', 'sweetness', 'taste buds', 'bitterness', 'hot chocolate']
#
#
# Cluster 6 (28 aspects):
#    ['bag', 'bags', 'bars', 'bottles', 'cans', 'cookies', 'bulk', 'each bag', 'pouches', 'pouch', 'chips', 'crackers', 'crumbs', 'waste', 'tea bag']
#
#
# Cluster 7 (24 aspects):
#    ['days', 'weeks', 'minutes', 'year', 'date', 'same time', 'times', 'years', 'hours', 'while', 'long time', 'age', 'hour', 'months', 'seconds']
#
#
# Cluster 8 (12 aspects):
#    ['reviews', 'review', 'other reviewers', 'disappointment', 'opinion', 'first time', 'one time', 'other reviews', 'another', 'rating', 'second time', 'another reviewer']
#
#
# Cluster 9 (21 aspects):
#    ['freezer', 'emeril', 'costco', 'amazon', 'stores', 'fridge', 'desk', 'customer service', 'store', 'grocery store', 'local stores', 'warehouse', 'refrigerator', 'local store', 'office']
#
#
# Cluster 10 (16 aspects):
#    ['container', 'packaging', 'pack', 'packs', 'box', 'delivery', 'package', 'boxes', 'items', 'packages', 'whole box', 'cardboard', 'packet', 'variety pack', 'shipment']
#
#
# Cluster 11 (30 aspects):
#    ['mistake', 'example', 'result', 'research', 'problem', 'drops', 'issue', 'subscribe', 'version', 'update', 'source', 'chance', 'consistency', 'try', 'change']
#
#
# Cluster 12 (39 aspects):
#    ['half', 'case', 'bit', 'other things', 'bunch', 'total', 'all', 'each', 'ones', 'whole lot', 'matter', 'some', 'any', 'mix', 'lots']
#
#
# Cluster 13 (30 aspects):
#    ['you', 'them', 'they', 'who', 'friends', 'her', 'which', 'myself', 'someone', 'him', 'some people', 'people', 'couple', 'person', 'others']
#
#
# Cluster 14 (12 aspects):
#    ['five stars', 'stars', 'star', 'jar', 'bill', 'two stars', 'zero stars', 'ball', 'one star', 'peach', 'basket', 'cherry']
#
#
# Cluster 15 (37 aspects):
#    ['freshness', 'milk', 'cream', 'spice', 'aroma', 'honey', 'ginger', 'oils', 'water', 'juice', 'salt', 'spicy', 'bottle', 'liquid', 'orange']
#
#
# Cluster 16 (58 aspects):
#    ['food', 'dog food', 'peanut butter', 'foods', 'spoon', 'servings', 'dry food', 'stomach', 'wet food', 'cake', 'fish', 'cooking', 'meat', 'fiber', 'their food']
#
#
# Cluster 17 (21 aspects):
#    ['same product', 'advantage', 'brand', 'manufacturer', 'company', 'other brands', 'convenience', 'different brand', 'another brand', 'great product', 'their website', 'alternative', 'products', 'companies', 'consumers']
#
#
# Cluster 18 (41 aspects):
#    ['list', 'garbage', 'label', 'things', 'contents', 'attention', 'type', 'quality', 'paper', 'experience', 'name', 'line', 'concept', 'quality control', 'product description']
#
#
# Cluster 19 (31 aspects):
#    ['subscription', 'price', 'value', 'cost', 'purchase', 'pricing', 'shipping', 'market', 'sale', 'seller', 'email', 'number', 'order', 'refund', 'replacement']
#
#
# Cluster 20 (18 aspects):
#    ['mine', 'fact', 'reason', 'comments', 'huge fan', 'no way', 'fan', 'choice', 'favorites', 'only way', 'some reason', 'favor', 'big fan', 'only reason', 'sense']
#
#
# Cluster 21 (21 aspects):
#    ['calories', 'grams', 'ounces', 'small amount', 'ounce', 'weight', 'tons', 'size', 'cents', 'amount', 'alot', 'lbs', 'same amount', 'pounds', 'quantity']
#
#
# Cluster 22 (62 aspects):
#    ['work', 'guests', 'machine', 'money', 'bottom', 'family', 'future', 'house', 'mother', 'country', 'mom', 'sister', 'bar', 'husband', 'morning']
#
#
# Cluster 23 (34 aspects):
#    ['ingredients', 'treat', 'ingredients list', 'sugars', 'sugar', 'sodium', 'pill', 'aspartame', 'splenda', 'stevia', 'soda', 'citric acid', 'artificial sweeteners', 'preservatives', 'vitamin c']
#
#
# Cluster 24 (16 aspects):
#    ['cats', 'kids', 'children', 'dogs', 'your dog', 'vet', 'your cat', 'our cats', 'dog', 'animals', 'cat', 'treats', 'our dog', 'puppy', 'your pet']

# %%
from collections import defaultdict
import numpy as np
import pandas as pd
import json

cluster_to_taxonomy = {
    0:  "food_ingredients",
    1:  "noise",
    2:  "noise",
    3:  "beverage",
    4:  "noise",
    5:  "taste_flavor",
    6:  "packaging_format",
    7:  "noise",
    8:  "noise",
    9:  "availability_location",
    10: "packaging_delivery",
    11: "noise",
    12: "noise",
    13: "noise",
    14: "noise",
    15: "freshness_aroma",
    16: "food_type",
    17: "brand_quality",
    18: "noise",
    19: "price_value",
    20: "noise",
    21: "quantity_size",
    22: "noise",
    23: "nutrition_ingredients",
    24: "target_user",
}

VALID_TAXONOMY = {
    "food_ingredients", "beverage", "taste_flavor", "packaging_format",
    "availability_location", "packaging_delivery", "freshness_aroma",
    "food_type", "brand_quality", "price_value", "quantity_size",
    "nutrition_ingredients", "target_user"
}

# Build raw_aspect → normalized_aspect lookup
aspect_to_taxonomy = {
    row["aspect"]: cluster_to_taxonomy[row["cluster"]]
    for _, row in cluster_df.iterrows()
}

# ── Per-product aspect vector construction ────────────────────────────────────
sentiment_map = {"positive": 1, "neutral": 0, "negative": -1}
taxonomy_labels = sorted(VALID_TAXONOMY)  # sorted for consistent column order
taxonomy_index = {label: i for i, label in enumerate(taxonomy_labels)}

product_vectors = defaultdict(lambda: defaultdict(list))

for review_id, pairs in review_aspect_map.items():
    product_id = data[review_id].get("product_id", review_id)
    for aspect, sentiment in pairs:
        if aspect in final_aspect_set:
            norm = aspect_to_taxonomy.get(aspect)
            if norm and norm in VALID_TAXONOMY:
                score = sentiment_map.get(sentiment.lower(), 0)
                product_vectors[product_id][norm].append(score)

# Average sentiment per aspect per product → fixed-length vector
records = []
for product_id, aspect_scores in product_vectors.items():
    vec = np.zeros(len(taxonomy_labels))
    for aspect_name, scores in aspect_scores.items():
        idx = taxonomy_index[aspect_name]
        vec[idx] = np.mean(scores)
    records.append({"product_id": product_id, **dict(zip(taxonomy_labels, vec))})

product_vector_df = pd.DataFrame(records).fillna(0)
print(f"Product vectors shape: {product_vector_df.shape}")
print(product_vector_df.head())

# Save outputs
product_vector_df.to_csv("models/absa/product_aspect_vectors.csv", index=False)
with open("models/absa/aspect_taxonomy_map.json", "w") as f:
    json.dump(aspect_to_taxonomy, f, indent=2)

print("\n✅ Stage 3 Complete!")
print("Saved: product_aspect_vectors.csv")
print("Saved: aspect_taxonomy_map.json")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 55
#      52 product_vectors = defaultdict(lambda: defaultdict(list))
#      54 for review_id, pairs in review_aspect_map.items():
# ---> 55     product_id = data[review_id].get("product_id", review_id)
#      56     for aspect, sentiment in pairs:
#      57         if aspect in final_aspect_set:
#
# AttributeError: 'list' object has no attribute 'get'

# %%
# Check structure
sample_key = list(data.keys())[0]
print("Key:", sample_key)
print("Value type:", type(data[sample_key]))
print("Value:", data[sample_key])
# Out:
# Key: 0
# Value type: <class 'list'>
# Value: [{'aspect': 'tea', 'sentiment': 'positive'}, {'aspect': 'flavor', 'sentiment': 'positive'}, {'aspect': 'cup', 'sentiment': 'positive'}, {'aspect': 'work', 'sentiment': 'positive'}, {'aspect': 'half', 'sentiment': 'positive'}, {'aspect': 'freezer', 'sentiment': 'positive'}, {'aspect': 'freshness', 'sentiment': 'positive'}, {'aspect': 'you', 'sentiment': 'positive'}, {'aspect': 'wrong buying', 'sentiment': 'positive'}]

# %%
# Check what the original loaded data looks like
import pandas as pd

# Try loading the original reviews file
df = pd.read_csv("path/to/your/original/reviews.csv")  # update path
print(df.columns.tolist())
print(df.head(2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 import pandas as pd
#       4 # Try loading the original reviews file
# ----> 5 df = pd.read_csv("path/to/your/original/reviews.csv")  # update path
#       6 print(df.columns.tolist())
#       7 print(df.head(2))
#
# File ~/main-env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/main-env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/main-env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/main-env/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/main-env/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/your/original/reviews.csv'
